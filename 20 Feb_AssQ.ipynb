# %%
#Q1. Explain GET and POST methods.
"""GET-It is the most common method which can be used to send data in the unencrypted form to the server.
exp: @app.route('/login',methods = ['GET']) 
POST-It is used to send the form data to the server. The server does not cache the data transmitted using the post method.
exp: @app.route('/login',methods = ['POST']) 
"""

# %%
#Q2. Why is request used in Flask?
"""
The Request, in Flask, is an object that contains all the data sent from the Client to Server. 
This data can be recovered using the GET/POST Methods. 
@app.route("/test2")  #https://purple-receptionist-lnqel.pwskills.app:5000/test2?x=20
def test2():
    data=request.args.get('x')
    return "this is my data input {}".format(data)
"""

# %%
#Q3. Why is redirect() used in Flask?
"""
Redirection in Flask can be done by returning a redirect response object, created by invoking the redirect() function. 
The same method is used for redirecting to other routes on the same application and external websites.
exp: 
from flask import Flask, redirect, url_for
appFlask = Flask(__name__)
@appFlask.route("/home")
def home():
return redirect(url_for('LoginPage'))
@appFlask.route("/LoginPage")
def LoginPage():
return "You are redirected to Login Page"
if __name__ == "__main__":
appFlask.run(debug=True)
"""

# %%
#Q4. What are templates in Flask? Why is the render_template() function used?
"""
flask facilitates us to return the response in the form of HTML templates.
@app.route('/')  
def message():  
      return "<html><body><h1>Hi, welcome to the website</h1></body></html>"  
      
Rendering external HTML files
Flask facilitates us to render the external HTML file instead of hardcoding the HTML in the view function.
@app.route('/')  
def message():  
      return render_template('message.html')  
"""

# %%
#Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
https://github.com/goyalshilpa/flask-assignment

# %% [markdown]
# ![image.png](attachment:ffd7a1be-9698-4b40-9eaa-735cc75f780c.png)
